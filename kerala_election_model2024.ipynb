# %% [markdown]
# # Election Prediction Model-2024

# %% [markdown]
# Data sourced from: https://myneta.info/

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## The data for training from 2009-2019

# %%
# reading the data and cleaning the data, that is the input
data=pd.read_excel('election.xlsx')
data['Total Assets'] = data['Total Assets'].apply(lambda x:str(x).split('~')[0]).apply(lambda x:str(x).split('_')[0]).apply(lambda x:str(x).split('\n')[0])
data['Total Assets'] = data['Total Assets'].apply(lambda x:str(x).replace(',','')).apply(lambda x:str(x).replace('Rs','').strip())
data['Liabilities'] = data['Liabilities'].apply(lambda x:str(x).split('~')[0]).apply(lambda x:str(x).split('_')[0]).apply(lambda x:str(x).split('\n')[0])
data['Liabilities'] = data['Liabilities'].apply(lambda x:str(x).replace(',','')).apply(lambda x:str(x).replace('Rs','').strip())
data['Total Assets'] = data['Total Assets'].apply(lambda x:x.replace('Nil',str(np.nan)))
data['Liabilities'] = data['Liabilities'].apply(lambda x:x.replace('Nil',str(np.nan)))
data['Total Assets'] = data['Total Assets'].astype(float)
data['Liabilities'] = data['Liabilities'].astype(float)
data['Total Assets'] = data['Total Assets'].fillna(data['Total Assets'].mean())
data['Liabilities'] = data['Liabilities'].fillna(0)

# %%
data.head(5)
# Out:
#                  Candidate Constituency Party  Criminal Cases  \
# 0     Shashi TharoorWinner   Trivandrum   INC               1
# 1  Adv Ramachandran Nair P   Trivandrum   CPI               0
# 2            Ajith Kumar K   Trivandrum   IND               0
# 3                   Dileep   Trivandrum   IND               0
# 4                G Ashokan   Trivandrum   IND               0
#
#                Education  Age  Total Assets  Liabilities  Year  Winner
# 0              Doctorate   53   212442472.0          0.0  2009       1
# 1  Graduate Professional   57     2157292.0     638195.0  2009       0
# 2              12th Pass   41       60000.0          0.0  2009       0
# 3               Graduate   28       40500.0          0.0  2009       0
# 4               8th Pass   47        2000.0          0.0  2009       0

# %%
data.isnull().sum()
# Out:
# Candidate         0
# Constituency      0
# Party             0
# Criminal Cases    0
# Education         0
# Age               0
# Total Assets      0
# Liabilities       0
# Year              0
# Winner            0
# dtype: int64

# %% [markdown]
# ## The data for 2024 prediction

# %%
# reading the data and cleaning the data, that is the for 2024 prediction
p_data = pd.read_excel('2024.xlsx')
p_data['Total Assets'] = p_data['Total Assets'].apply(lambda x:str(x).split('~')[0]).apply(lambda x:str(x).split('_')[0]).apply(lambda x:str(x).split('\n')[0])
p_data['Total Assets'] = p_data['Total Assets'].apply(lambda x:str(x).replace(',','')).apply(lambda x:str(x).replace('Rs','').strip())
p_data['Liabilities'] = p_data['Liabilities'].apply(lambda x:str(x).split('~')[0]).apply(lambda x:str(x).split('_')[0]).apply(lambda x:str(x).split('\n')[0])
p_data['Liabilities'] = p_data['Liabilities'].apply(lambda x:str(x).replace(',','')).apply(lambda x:str(x).replace('Rs','').strip())
p_data['Total Assets'] = p_data['Total Assets'].apply(lambda x:x.replace('Nil',str(np.nan)))
p_data['Liabilities'] = p_data['Liabilities'].apply(lambda x:x.replace('Nil',str(np.nan)))
p_data['Total Assets'] = p_data['Total Assets'].astype(float)
p_data['Liabilities'] = p_data['Liabilities'].astype(float)
p_data['Total Assets'] = p_data['Total Assets'].fillna(p_data['Total Assets'].mean())
p_data['Liabilities'] = p_data['Liabilities'].fillna(0)

# %%
p_data.head(5)
# Out:
#           Candidate Constituency    Party  Criminal Cases  \
# 0        A. M Ariff    Alappuzha   CPI(M)               3
# 1  Adv.K.M Shajahan    Alappuzha      IND               5
# 2           Arjunan    Alappuzha  SUCI(C)               0
# 3    Jayakrishnan P    Alappuzha      IND               0
# 4    Jyothi Abraham    Alappuzha      IND               0
#
#                Education  Age  Total Assets  Liabilities  Year
# 0  Graduate Professional   59  1.321630e+07    6095458.0  2024
# 1          Post Graduate   62  1.899451e+07    4490000.0  2024
# 2                 Others   60  3.646958e+06     160000.0  2024
# 3              12th Pass   49  9.105308e+06     483609.0  2024
# 4              10th Pass   43  2.346192e+07          0.0  2024

# %% [markdown]
# ## Adding Coalation related Opinion Poll percentage

# %%
# Taking into consideration the coalition politics from 2009-2019
NDA = ['BJP', 'Bharath Dharma Jana Sena']
UDF = ['INC','Kerala Congress (M)','KC(M)','Indian Union Muslim League','Revolutionary Socialist Party','IUML']
LDF = ['CPI','CPI(M)','Marxist Communist Party of India e(United)',"JD(U)",'RJD','JD(S)','CPM',]

# %%
NDA_24= ['BJP', 'Bharath Dharma Jana Sena']
UDF_24 = ['INC',"Kerala Congress",'Indian Union Muslim League','Revolutionary Socialist Party','IUML']
LDF_24 = ['CPI','CPI(M)','Marxist Communist Party of India e(United)',"JD(U)",'RJD','JD(S)','CPM','Kerala Congress (M)']

# %%
#TRAIN DATA

data["Coalition"] =  data["Party"].apply(lambda x :"NDA" if x in NDA else ("UDF" if x in UDF else ("LDF" if x in LDF else "OTHERS")))
data.loc[data["Year"] == 2019, "Vote_Percent"] = data[data["Year"] == 2019]["Coalition"].apply(lambda x: 43 if x == "UDF" else (32 if x == "LDF" else (13 if x == "NDA" else 0)))
data.loc[data["Year"] == 2009, "Vote_Percent"] = data[data["Year"] == 2009]["Coalition"].apply(lambda x: 45 if x == "UDF" else (37.9 if x == "LDF" else (6.3 if x == "NDA" else 0)))
data.loc[data["Year"] == 2014, "Vote_Percent"] = data[data["Year"] == 2014]["Coalition"].apply(lambda x: 35 if x == "UDF" else (28 if x == "LDF" else (10.5 if x == "NDA" else 0)))

# %%
#TEST DATA

p_data["Coalition"] =  p_data["Party"].apply(lambda x :"NDA" if x in NDA_24 else ("UDF" if x in UDF_24 else ("LDF" if x in LDF_24 else "OTHERS")))
p_data.loc[p_data["Year"] == 2024, "Vote_Percent"] = p_data[p_data["Year"] == 2024]["Coalition"].apply(lambda x: 41.58 if x == "UDF" else (36.67 if x == "LDF" else (20.08 if x == "NDA" else 0)))
p_data
# Out:
#                   Candidate Constituency                       Party  \
# 0                A. M Ariff    Alappuzha                      CPI(M)
# 1          Adv.K.M Shajahan    Alappuzha                         IND
# 2                   Arjunan    Alappuzha                     SUCI(C)
# 3            Jayakrishnan P    Alappuzha                         IND
# 4            Jyothi Abraham    Alappuzha                         IND
# ..                      ...          ...                         ...
# 183       Kodikunnil Suresh  Mavelikkara                         INC
# 184    Kozhuvasseril Suresh  Mavelikkara                         IND
# 185     Manthara Velayudhan  Mavelikkara                         IND
# 186  Santhosh Palathumpadan  Mavelikkara                         BSP
# 187         Suresh Nooranad  Mavelikkara  Ambedkarite Party of India
#
#      Criminal Cases              Education  Age  Total Assets  Liabilities  \
# 0                 3  Graduate Professional   59  1.321630e+07    6095458.0
# 1                 5          Post Graduate   62  1.899451e+07    4490000.0
# 2                 0                 Others   60  3.646958e+06     160000.0
# 3                 0              12th Pass   49  9.105308e+06     483609.0
# 4                 0              10th Pass   43  2.346192e+07          0.0
# ..              ...                    ...  ...           ...          ...
# 183               6  Graduate Professional   60  2.346192e+07          0.0
# 184               0               8th Pass   53  1.947354e+06      40000.0
# 185               0              12th Pass   53  1.412000e+06     250000.0
# 186               0              10th Pass   47  3.574000e+06     350000.0
# 187               0              10th Pass   43  3.003020e+05          0.0
#
#      Year Coalition  Vote_Percent
# 0    2024       LDF         36.67
# 1    2024    OTHERS          0.00
# 2    2024    OTHERS          0.00
# 3    2024    OTHERS          0.00
# 4    2024    OTHERS          0.00
# ..    ...       ...           ...
# 183  2024       UDF         41.58
# 184  2024    OTHERS          0.00
# 185  2024    OTHERS          0.00
# 186  2024    OTHERS          0.00
# 187  2024    OTHERS          0.00
#
# [188 rows x 11 columns]

# %%
# Removing Candidates from Data 
data = data.iloc[:,1:]
data.head(5)
# Out:
#   Constituency Party  Criminal Cases              Education  Age  \
# 0   Trivandrum   INC               1              Doctorate   53
# 1   Trivandrum   CPI               0  Graduate Professional   57
# 2   Trivandrum   IND               0              12th Pass   41
# 3   Trivandrum   IND               0               Graduate   28
# 4   Trivandrum   IND               0               8th Pass   47
#
#    Total Assets  Liabilities  Year  Winner Coalition  Vote_Percent
# 0   212442472.0          0.0  2009       1       UDF          45.0
# 1     2157292.0     638195.0  2009       0       LDF          37.9
# 2       60000.0          0.0  2009       0    OTHERS           0.0
# 3       40500.0          0.0  2009       0    OTHERS           0.0
# 4        2000.0          0.0  2009       0    OTHERS           0.0

# %%
#Removing candidates from P_data

p_data= p_data.iloc[:,1:]
p_data.head(5)
# Out:
#   Constituency    Party  Criminal Cases              Education  Age  \
# 0    Alappuzha   CPI(M)               3  Graduate Professional   59
# 1    Alappuzha      IND               5          Post Graduate   62
# 2    Alappuzha  SUCI(C)               0                 Others   60
# 3    Alappuzha      IND               0              12th Pass   49
# 4    Alappuzha      IND               0              10th Pass   43
#
#    Total Assets  Liabilities  Year Coalition  Vote_Percent
# 0  1.321630e+07    6095458.0  2024       LDF         36.67
# 1  1.899451e+07    4490000.0  2024    OTHERS          0.00
# 2  3.646958e+06     160000.0  2024    OTHERS          0.00
# 3  9.105308e+06     483609.0  2024    OTHERS          0.00
# 4  2.346192e+07          0.0  2024    OTHERS          0.00

# %%
party = {'CPI(M)': 1,
 'IND': 2,
 'SUCI(C)': 3,
 'INC': 4,
 'BSP': 5,
 'Bahujan Dravida Party': 6,
 'BJP': 7,
 'Twenty 20 Party': 8,
 'Bharath Dharma Jana Sena': 9,
 'Viduthalai Chiruthaigal Katchi': 10,
 'Bharatheeya Jawan Kisan Party': 11,
 'Ambedkarite Party of India': 12,
 'Revolutionary Socialist Party': 13,
 'Marxist Communist Party of India (United)': 14,
 'Kerala Congress': 15,
 'Samajwadi Jan Parishad': 16,
 'Kerala Congress (M)': 17,
 'Indian Union Muslim League': 18,
 'Peoples Party of India(secular)': 19,
 'CPI': 20,
 'New Labour Party': 21,
 'NCP': 22,
 'SHS': 23,
 'AAP': 24,
 'SDPI': 25,
 'Socialist Republican Party': 26,
 'RPI': 27,
 'RPI(A)': 28,
 'Pravasi Nivasi Party': 29,
 'RLD': 30,
 'CPM': 31,
 'AITC': 32,
 'Social Action Party': 33,
 'JD(U)': 34,
 'CPI(ML) Red star': 35,
 'Indian Gandhiyan Party': 36,
 'CPI(ML) Red Star': 35,
 'Socialist Janata (Democratic)': 38,
 'Welfare Party Of India': 39,
 'MUL': 40,
 'IUML': 18,
 'KEC': 15,
 'KEC(M)': 17,
 'Revolutionary Socialist Party of Kerala (B)': 44,
 'RJD': 45,
 'RSP': 13,
 'KC(M)': 17,
 'JD(S)': 48,
 'Welfare Party of India': 49,
 'Peoples Democratic Party': 50,
 'Samajwadi Forward Bloc': 51,
 'Rashtriya Samaj Paksha': 52,
 'Secular Democratic Congress': 53,
 'Agila India Makkal Kazhagam': 54,
 'National Labour Party': 55}

data  = data.replace(party)
p_data = p_data.replace(party)

# %%
Education = {'Graduate': 115,
 '12th Pass': 112,
 'Not Given': 100,
 '10th Pass': 104,
 'Others': 100,
 'Post Graduate': 117,
 'Graduate Professional': 118,
 '8th Pass': 108,
 'Doctorate': 120,
 'Literate': 105,
 '5th Pass': 105,
 'Illiterate': -1}
data = data.replace(Education)
p_data = p_data.replace(Education)

# %%
#To convert Constituency to Numeric Values
const_list = data["Constituency"].unique().tolist()
const = {const_list[i]: i+1001 for i,j in enumerate(const_list)}
data = data.replace(const)
p_data = p_data.replace(const)

# %%
pp = {'Thiruvananthapuram':1001}
p_data = p_data.replace(pp)

# %%
data.head(5)
# Out:
#    Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 0          1001      4               1        120   53   212442472.0
# 1          1001     20               0        118   57     2157292.0
# 2          1001      2               0        112   41       60000.0
# 3          1001      2               0        115   28       40500.0
# 4          1001      2               0        108   47        2000.0
#
#    Liabilities  Year  Winner Coalition  Vote_Percent
# 0          0.0  2009       1       UDF          45.0
# 1     638195.0  2009       0       LDF          37.9
# 2          0.0  2009       0    OTHERS           0.0
# 3          0.0  2009       0    OTHERS           0.0
# 4          0.0  2009       0    OTHERS           0.0

# %%
p_data.head(5)
# Out:
#    Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 0          1022      1               3        118   59  1.321630e+07
# 1          1022      2               5        117   62  1.899451e+07
# 2          1022      3               0        100   60  3.646958e+06
# 3          1022      2               0        112   49  9.105308e+06
# 4          1022      2               0        104   43  2.346192e+07
#
#    Liabilities  Year Coalition  Vote_Percent
# 0    6095458.0  2024       LDF         36.67
# 1    4490000.0  2024    OTHERS          0.00
# 2     160000.0  2024    OTHERS          0.00
# 3     483609.0  2024    OTHERS          0.00
# 4          0.0  2024    OTHERS          0.00

# %%
data= data.loc[:, ["Constituency","Party", "Criminal Cases", "Education", "Age", "Total Assets", "Liabilities", "Year","Winner","Vote_Percent"]]
data.head(5)
# Out:
#    Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 0          1001      4               1        120   53   212442472.0
# 1          1001     20               0        118   57     2157292.0
# 2          1001      2               0        112   41       60000.0
# 3          1001      2               0        115   28       40500.0
# 4          1001      2               0        108   47        2000.0
#
#    Liabilities  Year  Winner  Vote_Percent
# 0          0.0  2009       1          45.0
# 1     638195.0  2009       0          37.9
# 2          0.0  2009       0           0.0
# 3          0.0  2009       0           0.0
# 4          0.0  2009       0           0.0

# %%
p_data= p_data.loc[:, ["Constituency","Party", "Criminal Cases", "Education", "Age", "Total Assets", "Liabilities", "Year","Vote_Percent"]]
p_data.head(5)
# Out:
#    Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 0          1022      1               3        118   59  1.321630e+07
# 1          1022      2               5        117   62  1.899451e+07
# 2          1022      3               0        100   60  3.646958e+06
# 3          1022      2               0        112   49  9.105308e+06
# 4          1022      2               0        104   43  2.346192e+07
#
#    Liabilities  Year  Vote_Percent
# 0    6095458.0  2024         36.67
# 1    4490000.0  2024          0.00
# 2     160000.0  2024          0.00
# 3     483609.0  2024          0.00
# 4          0.0  2024          0.00

# %% [markdown]
# ## Using RandomFOrest

# %%
import joblib

# %% [markdown]
# ### We trained the model with  Random Forest
#
# Accuracy - 0.9610
#
# AUC - 0.9427
#
# Recall - 0.6550
#
# Precision - 0.9217
#
# F1 Score - 0.7353

# %%
# Load the model from the file
model = joblib.load('election_model.joblib')

# %%
# used to predict
pdf = predict_model(model,data = p_data)
pdf
# Out:
#      Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 0            1022      1               3        118   59    13216302.0
# 1            1022      2               5        117   62    18994512.0
# 2            1022      3               0        100   60     3646958.0
# 3            1022      2               0        112   49     9105308.0
# 4            1022      2               0        104   43    23461924.0
# ..            ...    ...             ...        ...  ...           ...
# 183          1018      4               6        118   60    23461924.0
# 184          1018      2               0        108   53     1947354.0
# 185          1018      2               0        112   53     1412000.0
# 186          1018      5               0        104   47     3574000.0
# 187          1018     12               0        104   43      300302.0
#
#      Liabilities  Year  Vote_Percent  prediction_label  prediction_score
# 0      6095458.0  2024     36.669998                 0              0.51
# 1      4490000.0  2024      0.000000                 0              0.73
# 2       160000.0  2024      0.000000                 0              0.94
# 3       483609.0  2024      0.000000                 0              0.94
# 4            0.0  2024      0.000000                 0              0.90
# ..           ...   ...           ...               ...               ...
# 183          0.0  2024     41.580002                 1              0.88
# 184      40000.0  2024      0.000000                 0              0.95
# 185     250000.0  2024      0.000000                 0              0.95
# 186     350000.0  2024      0.000000                 0              0.92
# 187          0.0  2024      0.000000                 0              0.91
#
# [188 rows x 11 columns]

# %%
def map_const(name):
    for key, value in const.items():
        if value == name:
            return key
    return None  # Return None if no match found

# Apply the mapping function to create the "Candy" column in Final
pdf["Constiuency Name"] = pdf["Constituency"].apply(map_const)

#________________________________________________________________________#

def map_party(name):
    for key, value in party.items():
        if value == name:
            return key
    return None  # Return None if no match found

# Apply the mapping function to create the "Candy" column in Final
pdf["Party Name"] = pdf["Party"].apply(map_party)

#________________________________________________________________________#

# %%
# to save prediction  as csv
pdf.to_csv("Results.csv")

# %%
pdf
# Out:
#      Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 0            1022      1               3        118   59    13216302.0
# 1            1022      2               5        117   62    18994512.0
# 2            1022      3               0        100   60     3646958.0
# 3            1022      2               0        112   49     9105308.0
# 4            1022      2               0        104   43    23461924.0
# ..            ...    ...             ...        ...  ...           ...
# 183          1018      4               6        118   60    23461924.0
# 184          1018      2               0        108   53     1947354.0
# 185          1018      2               0        112   53     1412000.0
# 186          1018      5               0        104   47     3574000.0
# 187          1018     12               0        104   43      300302.0
#
#      Liabilities  Year  Vote_Percent  prediction_label  prediction_score  \
# 0      6095458.0  2024     36.669998                 0              0.51
# 1      4490000.0  2024      0.000000                 0              0.73
# 2       160000.0  2024      0.000000                 0              0.94
# 3       483609.0  2024      0.000000                 0              0.94
# 4            0.0  2024      0.000000                 0              0.90
# ..           ...   ...           ...               ...               ...
# 183          0.0  2024     41.580002                 1              0.88
# 184      40000.0  2024      0.000000                 0              0.95
# 185     250000.0  2024      0.000000                 0              0.95
# 186     350000.0  2024      0.000000                 0              0.92
# 187          0.0  2024      0.000000                 0              0.91
#
#     Constiuency Name                  Party Name
# 0          Alappuzha                      CPI(M)
# 1          Alappuzha                         IND
# 2          Alappuzha                     SUCI(C)
# 3          Alappuzha                         IND
# 4          Alappuzha                         IND
# ..               ...                         ...
# 183      Mavelikkara                         INC
# 184      Mavelikkara                         IND
# 185      Mavelikkara                         IND
# 186      Mavelikkara                         BSP
# 187      Mavelikkara  Ambedkarite Party of India
#
# [188 rows x 13 columns]

# %%
# Add Coalition column
pdf["Coalition"] =  pdf["Party Name"].apply(lambda x :"NDA" if x in NDA_24 else ("UDF" if x in UDF_24 else ("LDF" if x in LDF_24 else "OTHERS")))

# %%
pdf
# Out:
#      Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 0            1022      1               3        118   59    13216302.0
# 1            1022      2               5        117   62    18994512.0
# 2            1022      3               0        100   60     3646958.0
# 3            1022      2               0        112   49     9105308.0
# 4            1022      2               0        104   43    23461924.0
# ..            ...    ...             ...        ...  ...           ...
# 183          1018      4               6        118   60    23461924.0
# 184          1018      2               0        108   53     1947354.0
# 185          1018      2               0        112   53     1412000.0
# 186          1018      5               0        104   47     3574000.0
# 187          1018     12               0        104   43      300302.0
#
#      Liabilities  Year  Vote_Percent  prediction_label  prediction_score  \
# 0      6095458.0  2024     36.669998                 0              0.51
# 1      4490000.0  2024      0.000000                 0              0.73
# 2       160000.0  2024      0.000000                 0              0.94
# 3       483609.0  2024      0.000000                 0              0.94
# 4            0.0  2024      0.000000                 0              0.90
# ..           ...   ...           ...               ...               ...
# 183          0.0  2024     41.580002                 1              0.88
# 184      40000.0  2024      0.000000                 0              0.95
# 185     250000.0  2024      0.000000                 0              0.95
# 186     350000.0  2024      0.000000                 0              0.92
# 187          0.0  2024      0.000000                 0              0.91
#
#     Constiuency Name                  Party Name Coalition
# 0          Alappuzha                      CPI(M)       LDF
# 1          Alappuzha                         IND    OTHERS
# 2          Alappuzha                     SUCI(C)    OTHERS
# 3          Alappuzha                         IND    OTHERS
# 4          Alappuzha                         IND    OTHERS
# ..               ...                         ...       ...
# 183      Mavelikkara                         INC       UDF
# 184      Mavelikkara                         IND    OTHERS
# 185      Mavelikkara                         IND    OTHERS
# 186      Mavelikkara                         BSP    OTHERS
# 187      Mavelikkara  Ambedkarite Party of India    OTHERS
#
# [188 rows x 14 columns]

# %%
# Get only winner data
pdf = pdf[pdf['prediction_label']==1]

# %%
pdf
# Out:
#      Constituency  Party  Criminal Cases  Education  Age  Total Assets  \
# 5            1022      4               1        117   61    36342460.0
# 13           1005      4               9        104   38    23461924.0
# 18           1008      1               1        118   58    23461924.0
# 22           1009      4               5        115   71    35020208.0
# 26           1009      1               0        117   68    40306184.0
# 34           1011      4              10        115   40    23461924.0
# 39           1012      4              88        117   42    20797764.0
# 51           1010      4              14        117   75    62979920.0
# 53           1010      1               9        118   63    14448542.0
# 61           1013      1               0        104   74    27545988.0
# 65           1013      4               6        115   70    32432136.0
# 71           1014      1               1        115   67    23461924.0
# 73           1014     13               5        118   63    49194900.0
# 79           1015     15               5        118   68    95105392.0
# 89           1015     17               3        115   71    31650660.0
# 98           1016      1               2        112   70     9327253.0
# 99           1016      4               4        115   71    24936776.0
# 107          1017     18               1        104   77    20252292.0
# 117          1002      4               5        115   67    12471856.0
# 122          1020     20               1        115   60    16112844.0
# 127          1020      4              19        117   53   203961856.0
# 130          1019      1               4        118   67    15728421.0
# 136          1019      4              47        117   41     9934524.0
# 144          1003      4               9        115   67    23461924.0
# 160          1001      4              12        120   68   560656128.0
# 164          1006     18               1        120   65    21977344.0
# 169          1004      1               1        118   67    11151017.0
# 178          1004      4               5        115   54    23461924.0
# 183          1018      4               6        118   60    23461924.0
#
#      Liabilities  Year  Vote_Percent  prediction_label  prediction_score  \
# 5       272817.0  2024     41.580002                 1              0.72
# 13           0.0  2024     41.580002                 1              0.65
# 18           0.0  2024     36.669998                 1              0.55
# 22     7893411.0  2024     41.580002                 1              0.85
# 26     4482706.0  2024     36.669998                 1              0.59
# 34           0.0  2024     41.580002                 1              0.66
# 39     3619970.0  2024     41.580002                 1              0.80
# 51     5933624.0  2024     41.580002                 1              0.83
# 53           0.0  2024     36.669998                 1              0.61
# 61           0.0  2024     36.669998                 1              0.60
# 65      678829.0  2024     41.580002                 1              0.89
# 71           0.0  2024     36.669998                 1              0.66
# 73     3800000.0  2024     41.580002                 1              0.84
# 79     1300000.0  2024     41.580002                 1              0.84
# 89           0.0  2024     36.669998                 1              0.75
# 98      750000.0  2024     36.669998                 1              0.55
# 99    12600000.0  2024     41.580002                 1              0.89
# 107          0.0  2024     41.580002                 1              0.87
# 117   15673065.0  2024     41.580002                 1              0.87
# 122          0.0  2024     36.669998                 1              0.58
# 127    4979184.0  2024     41.580002                 1              0.80
# 130     435800.0  2024     36.669998                 1              0.61
# 136    1500000.0  2024     41.580002                 1              0.73
# 144          0.0  2024     41.580002                 1              0.82
# 160          0.0  2024     41.580002                 1              0.81
# 164          0.0  2024     41.580002                 1              0.93
# 169          0.0  2024     36.669998                 1              0.65
# 178          0.0  2024     41.580002                 1              0.78
# 183          0.0  2024     41.580002                 1              0.88
#
#     Constiuency Name                     Party Name Coalition
# 5          Alappuzha                            INC       UDF
# 13           Alathur                            INC       UDF
# 18          Attingal                         CPI(M)       LDF
# 22         Chalakudy                            INC       UDF
# 26         Chalakudy                         CPI(M)       LDF
# 34         Ernakulam                            INC       UDF
# 39            Idukki                            INC       UDF
# 51            Kannur                            INC       UDF
# 53            Kannur                         CPI(M)       LDF
# 61          Kasargod                         CPI(M)       LDF
# 65          Kasargod                            INC       UDF
# 71            Kollam                         CPI(M)       LDF
# 73            Kollam  Revolutionary Socialist Party       UDF
# 79          Kottayam                Kerala Congress       UDF
# 89          Kottayam            Kerala Congress (M)       LDF
# 98         Kozhikode                         CPI(M)       LDF
# 99         Kozhikode                            INC       UDF
# 107       Malappuram     Indian Union Muslim League       UDF
# 117   Pathanamthitta                            INC       UDF
# 122          Wayanad                            CPI       LDF
# 127          Wayanad                            INC       UDF
# 130         Vadakara                         CPI(M)       LDF
# 136         Vadakara                            INC       UDF
# 144         Thrissur                            INC       UDF
# 160       Trivandrum                            INC       UDF
# 164          Ponnani     Indian Union Muslim League       UDF
# 169         Palakkad                         CPI(M)       LDF
# 178         Palakkad                            INC       UDF
# 183      Mavelikkara                            INC       UDF

# %%
# to select relevant column only
pdf = pdf.iloc[:,9:]

# %%
pdf
# Out:
#      prediction_label  prediction_score Constiuency Name  \
# 5                   1              0.72        Alappuzha
# 13                  1              0.65          Alathur
# 18                  1              0.55         Attingal
# 22                  1              0.85        Chalakudy
# 26                  1              0.59        Chalakudy
# 34                  1              0.66        Ernakulam
# 39                  1              0.80           Idukki
# 51                  1              0.83           Kannur
# 53                  1              0.61           Kannur
# 61                  1              0.60         Kasargod
# 65                  1              0.89         Kasargod
# 71                  1              0.66           Kollam
# 73                  1              0.84           Kollam
# 79                  1              0.84         Kottayam
# 89                  1              0.75         Kottayam
# 98                  1              0.55        Kozhikode
# 99                  1              0.89        Kozhikode
# 107                 1              0.87       Malappuram
# 117                 1              0.87   Pathanamthitta
# 122                 1              0.58          Wayanad
# 127                 1              0.80          Wayanad
# 130                 1              0.61         Vadakara
# 136                 1              0.73         Vadakara
# 144                 1              0.82         Thrissur
# 160                 1              0.81       Trivandrum
# 164                 1              0.93          Ponnani
# 169                 1              0.65         Palakkad
# 178                 1              0.78         Palakkad
# 183                 1              0.88      Mavelikkara
#
#                         Party Name Coalition
# 5                              INC       UDF
# 13                             INC       UDF
# 18                          CPI(M)       LDF
# 22                             INC       UDF
# 26                          CPI(M)       LDF
# 34                             INC       UDF
# 39                             INC       UDF
# 51                             INC       UDF
# 53                          CPI(M)       LDF
# 61                          CPI(M)       LDF
# 65                             INC       UDF
# 71                          CPI(M)       LDF
# 73   Revolutionary Socialist Party       UDF
# 79                 Kerala Congress       UDF
# 89             Kerala Congress (M)       LDF
# 98                          CPI(M)       LDF
# 99                             INC       UDF
# 107     Indian Union Muslim League       UDF
# 117                            INC       UDF
# 122                            CPI       LDF
# 127                            INC       UDF
# 130                         CPI(M)       LDF
# 136                            INC       UDF
# 144                            INC       UDF
# 160                            INC       UDF
# 164     Indian Union Muslim League       UDF
# 169                         CPI(M)       LDF
# 178                            INC       UDF
# 183                            INC       UDF

# %% [markdown]
# ## To arrive a conclusion we manually gave  a metric
#
# if same constituencies have multiple winners we create a column and give Contest status
#
# it the prediction score is too near by we will conclude too close
#
# and at the end we take one who has highest prediction score as winner

# %%
def filter_and_label(group):
    if len(group) == 1:
        group['Contest Type'] = 'Normal'
        return group
    else:
        sorted_group = group.sort_values(by='prediction_score', ascending=False)
        if sorted_group.iloc[0]['prediction_score'] - sorted_group.iloc[1]['prediction_score'] < 0.1:
            sorted_group['Contest Type'] = 'Too Close'
            return sorted_group
        if sorted_group.iloc[0]['prediction_score'] - sorted_group.iloc[1]['prediction_score'] < 0.2:
            sorted_group['Contest Type'] = 'Close'
            return sorted_group
        else:
            top_row = sorted_group.iloc[[0]]
            top_row['Contest Type'] = 'Normal'
            return top_row

# Apply the function to each group
result = pdf.groupby('Constiuency Name').apply(filter_and_label).reset_index(drop=True)

result
# Out:
#     prediction_label  prediction_score Constiuency Name  \
# 0                  1              0.72        Alappuzha
# 1                  1              0.65          Alathur
# 2                  1              0.55         Attingal
# 3                  1              0.85        Chalakudy
# 4                  1              0.66        Ernakulam
# 5                  1              0.80           Idukki
# 6                  1              0.83           Kannur
# 7                  1              0.89         Kasargod
# 8                  1              0.84           Kollam
# 9                  1              0.66           Kollam
# 10                 1              0.84         Kottayam
# 11                 1              0.75         Kottayam
# 12                 1              0.89        Kozhikode
# 13                 1              0.87       Malappuram
# 14                 1              0.88      Mavelikkara
# 15                 1              0.78         Palakkad
# 16                 1              0.65         Palakkad
# 17                 1              0.87   Pathanamthitta
# 18                 1              0.93          Ponnani
# 19                 1              0.82         Thrissur
# 20                 1              0.81       Trivandrum
# 21                 1              0.73         Vadakara
# 22                 1              0.61         Vadakara
# 23                 1              0.80          Wayanad
#
#                        Party Name Coalition Contest Type
# 0                             INC       UDF       Normal
# 1                             INC       UDF       Normal
# 2                          CPI(M)       LDF       Normal
# 3                             INC       UDF       Normal
# 4                             INC       UDF       Normal
# 5                             INC       UDF       Normal
# 6                             INC       UDF       Normal
# 7                             INC       UDF       Normal
# 8   Revolutionary Socialist Party       UDF        Close
# 9                          CPI(M)       LDF        Close
# 10                Kerala Congress       UDF    Too Close
# 11            Kerala Congress (M)       LDF    Too Close
# 12                            INC       UDF       Normal
# 13     Indian Union Muslim League       UDF       Normal
# 14                            INC       UDF       Normal
# 15                            INC       UDF        Close
# 16                         CPI(M)       LDF        Close
# 17                            INC       UDF       Normal
# 18     Indian Union Muslim League       UDF       Normal
# 19                            INC       UDF       Normal
# 20                            INC       UDF       Normal
# 21                            INC       UDF        Close
# 22                         CPI(M)       LDF        Close
# 23                            INC       UDF       Normal

# %% [markdown]
# Renaming columns for making it meaningful

# %%
# below code we take the result and select only the one with best prediction score
f1_df = result.loc[result.groupby('Constiuency Name')['prediction_score'].idxmax()]
f1_df = f1_df.rename(columns={
    'prediction_label': 'Label',
    'prediction_score': 'Prediction Score',
    'Constiuency Name': 'Constituency Name',
    'Party Name': 'Winning Party Name',
    'Coalition': 'Winning Coalition Name',
    'Contest Type': 'Contest Type'
})
f1_df
# Out:
#     Label  Prediction Score Constituency Name             Winning Party Name  \
# 0       1              0.72         Alappuzha                            INC
# 1       1              0.65           Alathur                            INC
# 2       1              0.55          Attingal                         CPI(M)
# 3       1              0.85         Chalakudy                            INC
# 4       1              0.66         Ernakulam                            INC
# 5       1              0.80            Idukki                            INC
# 6       1              0.83            Kannur                            INC
# 7       1              0.89          Kasargod                            INC
# 8       1              0.84            Kollam  Revolutionary Socialist Party
# 10      1              0.84          Kottayam                Kerala Congress
# 12      1              0.89         Kozhikode                            INC
# 13      1              0.87        Malappuram     Indian Union Muslim League
# 14      1              0.88       Mavelikkara                            INC
# 15      1              0.78          Palakkad                            INC
# 17      1              0.87    Pathanamthitta                            INC
# 18      1              0.93           Ponnani     Indian Union Muslim League
# 19      1              0.82          Thrissur                            INC
# 20      1              0.81        Trivandrum                            INC
# 21      1              0.73          Vadakara                            INC
# 23      1              0.80           Wayanad                            INC
#
#    Winning Coalition Name Contest Type
# 0                     UDF       Normal
# 1                     UDF       Normal
# 2                     LDF       Normal
# 3                     UDF       Normal
# 4                     UDF       Normal
# 5                     UDF       Normal
# 6                     UDF       Normal
# 7                     UDF       Normal
# 8                     UDF        Close
# 10                    UDF    Too Close
# 12                    UDF       Normal
# 13                    UDF       Normal
# 14                    UDF       Normal
# 15                    UDF        Close
# 17                    UDF       Normal
# 18                    UDF       Normal
# 19                    UDF       Normal
# 20                    UDF       Normal
# 21                    UDF        Close
# 23                    UDF       Normal

# %%
# Remove Prediction Label-- this would be final result
f1_df[['Constituency Name','Winning Party Name', 'Winning Coalition Name', 'Prediction Score', 'Contest Type']]
# Out:
#    Constituency Name             Winning Party Name Winning Coalition Name  \
# 0          Alappuzha                            INC                    UDF
# 1            Alathur                            INC                    UDF
# 2           Attingal                         CPI(M)                    LDF
# 3          Chalakudy                            INC                    UDF
# 4          Ernakulam                            INC                    UDF
# 5             Idukki                            INC                    UDF
# 6             Kannur                            INC                    UDF
# 7           Kasargod                            INC                    UDF
# 8             Kollam  Revolutionary Socialist Party                    UDF
# 10          Kottayam                Kerala Congress                    UDF
# 12         Kozhikode                            INC                    UDF
# 13        Malappuram     Indian Union Muslim League                    UDF
# 14       Mavelikkara                            INC                    UDF
# 15          Palakkad                            INC                    UDF
# 17    Pathanamthitta                            INC                    UDF
# 18           Ponnani     Indian Union Muslim League                    UDF
# 19          Thrissur                            INC                    UDF
# 20        Trivandrum                            INC                    UDF
# 21          Vadakara                            INC                    UDF
# 23           Wayanad                            INC                    UDF
#
#     Prediction Score Contest Type
# 0               0.72       Normal
# 1               0.65       Normal
# 2               0.55       Normal
# 3               0.85       Normal
# 4               0.66       Normal
# 5               0.80       Normal
# 6               0.83       Normal
# 7               0.89       Normal
# 8               0.84        Close
# 10              0.84    Too Close
# 12              0.89       Normal
# 13              0.87       Normal
# 14              0.88       Normal
# 15              0.78        Close
# 17              0.87       Normal
# 18              0.93       Normal
# 19              0.82       Normal
# 20              0.81       Normal
# 21              0.73        Close
# 23              0.80       Normal

# %% [markdown]
# ### To manually correct codes
#
# eg : Sometimes BJP and Bharatiya Janatha Party , INC and  Indian National Congress will be there so we need single code for it

# %%
plot_model(model, plot = 'feature')

# %%
plot_model(model, plot = 'auc')
